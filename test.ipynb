# %%
var modulus = 3;
var i = -7;


if (i >= 0)
    Console.WriteLine(i % modulus);
else
    Console.WriteLine((modulus + (i % modulus)) % modulus);


// modulus + (i % modulus)

// 0 1 2 3 4 5
# Out:
# 2
